# %% [markdown]
# <a href="https://colab.research.google.com/github/Zaid-sh05/AI-Driven-Zone-Water-Detection/blob/main/aau_robotics2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()

import zipfile
import os

zip_path = list(uploaded.keys())[0]

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall('/content/data')

os.listdir('/content/data')
# Out:
#      <input type="file" id="files-68054693-57c9-46dc-8d8c-1d4191a3fdb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68054693-57c9-46dc-8d8c-1d4191a3fdb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('/content/data/jordan_v2_train.csv')

df.head()
# Out:
#              Timestamp Governorate   Zone_ID      Segment_ID  hour  \
# 0  2020-01-01T00:00:00       Amman  ZN-AM-02   AMM-AM-02-79m     0
# 1  2020-01-01T00:15:00       Amman  ZN-AM-04  AMM-AM-04-140m     0
# 2  2020-01-01T00:30:00       Irbid  ZN-IR-04  IRB-IR-04-205m     0
# 3  2020-01-01T00:45:00      Mafraq  ZN-MF-01  MAF-MF-01-436m     0
# 4  2020-01-01T01:00:00       Amman  ZN-AM-03  AMM-AM-03-350m     1
#
#    day_of_week  month  is_ramadan  is_eid  is_summer  ...  Flow_Ratio  \
# 0            2      1           0       0          0  ...     0.87883
# 1            2      1           0       0          0  ...     0.99559
# 2            2      1           0       0          0  ...     0.99081
# 3            2      1           0       0          0  ...     1.00000
# 4            2      1           0       0          0  ...     0.96892
#
#    Pressure_Ratio  Loss_Per_100m  DP_Predicted  DP_Deviation  Flow_DP_Ratio  \
# ...

# %%
import pandas as pd

df_train = pd.read_csv('/content/data/jordan_v2_train.csv')

df_train_shuffled = df_train.sample(frac=1, random_state=42)

df_train_shuffled.head()
# Out:
#                  Timestamp Governorate   Zone_ID      Segment_ID  hour  \
# 47044  2021-05-05T01:00:00       Balqa  ZN-BQ-03  BAL-BQ-03-147m     1
# 44295  2021-04-06T09:45:00       Amman  ZN-AM-03  AMM-AM-03-350m     9
# 74783  2022-02-17T23:45:00       Irbid  ZN-IR-04  IRB-IR-04-205m    23
# 70975  2022-01-09T07:45:00      Ajloun  ZN-AJ-01  AJL-AJ-01-427m     7
# 46645  2021-04-30T21:15:00       Amman  ZN-AM-05  AMM-AM-05-265m    21
#
#        day_of_week  month  is_ramadan  is_eid  is_summer  ...  Flow_Ratio  \
# 47044            2      5           1       0          0  ...     0.98998
# 44295            1      4           0       0          0  ...     0.98111
# 74783            3      2           0       0          0  ...     0.99188
# 70975            6      1           0       0          0  ...     0.97865
# 46645            4      4           1       0          0  ...     0.98668
#
#        Pressure_Ratio  Loss_Per_100m  DP_Predicted  DP_Deviation  \
# ...

# %%
# !python /content/data/jordan_colab_pipeline_fin.py
# Out:
# 2026-03-29 05:51:04.124881: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-29 05:51:04.142260: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-29 05:51:04.164304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774763464.194355    8541 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774763464.203427    8541 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !ls colab_outputs
# Out:
# alert_log.csv			model_isolation_forest.pkl
# dashboard_interactive.html	model_lstm.keras
# evaluation_metrics.json		model_random_forest.pkl
# fig1_lstm_training_curve.png	scaler_if.pkl
# fig2_confusion_matrix.png	scaler_lstm.pkl
# fig3_per_class_metrics.png	scaler_lstm_y.pkl
# fig4_feature_importance.png	scaler_rf.pkl
# fig5_spatial_feature_space.png	table1_model_comparison.csv
# fig6_flow_dp_ratio_dist.png	table2_per_class_metrics.csv
# fig7_governorate_rates.png	table3_dataset_description.csv
# fig8_scada_dashboard.png	test_predictions.csv

# %%
# !pip install -q flask scikit-learn pandas numpy joblib

# %%
exec(open('/content/data/real_time_monitoring.py').read())
# Out:
# ✅ Packages ready.
# ✅ ML models loaded.
# ✅ LSTM loaded.
# ✅ All ready. Launching...
# ✅ Background thread started (35s cycle).
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# ...
# 🚀  AQUAGUARD DASHBOARD IS LIVE
# ...
# 🔗  https://5000-m-s-kkb-use1b1-y4v14nrvmvdc-b.us-east1-1.prod.colab.dev
# ...
#     وضع النموذج: ML (RF+IF+LSTM)
#     التحديث التلقائي كل 35 ثانية
# ...
